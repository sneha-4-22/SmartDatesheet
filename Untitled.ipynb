# %%
import pandas as pd

# %%
excel_file = 'BBA & MBA PROGRAM STRUCTURE EVEN SEMESTER 2024 (2).xlsx'

# %%
df = pd.read_excel(excel_file)

# %%
# Extract the values from the first column of the DataFrame
my_list = df.iloc[:, 0].tolist()

# Print the list of items
print("Your list of items:")
for index, item in enumerate(my_list, start=1):
    print(f"{index}. {item}")
# Out:
# Your list of items:
# 1. S No
# 2. 1
# 3. 2
# 4. 3
# 5. nan
# 6. ELECTIVE
# 7. FINANCE AND ACCOUNTS
# 8. 4
# 9. 5
# 10. 6
# 11. 7
# 12. 8
# 13. Entrepreneurship & Family Business Specialization
# 14. 9
# 15. 10
# 16. 11
# 17. 12
# 18. 13
# 19. Health Care Management Specialization
# 20. 14
# 21. 15
# 22. 16
# 23. 17
# 24. 18
# 25. Global Operations Management
# 26. 19
# 27. 20
# 28. 21
# 29. 22
# 30. Business Analytics Specialization
# 31. 23
# 32. 24
# 33. 25
# 34. 26
# 35. 27

# %%
df
# Out:
#                                           SEMESTER II     Unnamed: 1  \
# 0                                                S No  SUBJECT CODES
# 1                                                   1        MCH114B
# 2                                                   2        MCH115B
# 3                                                   3        CSS108B
# 4                                                 NaN            NaN
# 5                                            ELECTIVE            NaN
# 6                               FINANCE AND ACCOUNTS             NaN
# 7                                                   4        MCH113B
# 8                                                   5        MCH122B
# 9                                                   6        MCH140B
# 10                                                  7         EDH147
# 11                                                  8        MCH137B
# 12  Entrepreneurship & Family Business Specialization            NaN
# 13                                                  9        MCH113B
# 14                                                 10        MCH124B
# 15                                                 11        MCH125B
# 16                                                 12         EDH147
# 17                                                 13        MCH137B
# 18              Health Care Management Specialization            NaN
# 19                                                 14        MCH119B
# 20                                                 15        MCH126B
# 21                                                 16        MCH141B
# 22                                                 17        MCH127B
# 23                                                 18        MCH137B
# 24                      Global Operations Management             NaN
# 25                                                 19        MCH113B
# 26                                                 20         EDH147
# 27                                                 21        MCH117B
# 28                                                 22        MCH137B
# 29                  Business Analytics Specialization            NaN
# 30                                                 23         EDH147
# 31                                                 24        MCH136B
# 32                                                 25        MCH142B
# 33                                                 26        MCH135B
# 34                                                 27        MCH137B
#
#                                            Unnamed: 2           Unnamed: 3  \
# 0                                        SUBJECT NAME  OFFERING DEPARTMENT
# 1                           HUMAN RESOURCE MANAGEMENT                  DMC
# 2                                FINANCIAL MANAGEMENT                  DMC
# 3                                      ADVANCED EXCEL                  CST
# 4                                                 NaN                  NaN
# 5                                                 NaN                  NaN
# 6                                                 NaN                  NaN
# 7                                     MACRO ECONOMICS                  DMC
# 8                                   COST  ACCOUNTING                   DMC
# 9                                  FINANCIAL SERVICES                  DMC
# 10                BUSINESS COMMUNICATION SKILLS- II                    EDU
# 11                                  INDUSTRY PROJECT                   DMC
# 12                                                NaN                  NaN
# 13                                    MACRO ECONOMICS                  DMC
# 14  INTRODUCTION TO  FAMILY BUSINESS MANAGEMENT (EFB)                  DMC
# 15        CREATIVITY & INNOVATION IN ENTREPRENEURSHIP                  DMC
# 16                BUSINESS COMMUNICATION SKILLS- II                    EDU
# 17                                  INDUSTRY PROJECT                   DMC
# 18                                                NaN                  NaN
# 19     FINANCING & BUSINESS DEVELOPMENT OF HOSPITALS                   DMC
# 20                          HEALTHCARE COMMUNICATION                   DMC
# 21             Hospital Hazards and waste management                   DMC
# 22                             HEALTHCARE ECONOMICS                    DMC
# 23                                  INDUSTRY PROJECT                   DMC
# 24                                                NaN                  NaN
# 25                                    MACRO ECONOMICS                  DMC
# 26                BUSINESS COMMUNICATION SKILLS- II                    EDU
# 27                         FUNDAMENTALS OF LOGISTICS                    ME
# 28                                  INDUSTRY PROJECT                   DMC
# 29                                                NaN                  NaN
# 30                BUSINESS COMMUNICATION SKILLS- II                    EDU
# 31                              MANAGERIAL ECONOMICS                   DMC
# 32                    Structured Query Language (SQL)                  DMC
# 33                                      DATA CLEANING                  DMC
# 34                                  INDUSTRY PROJECT                   DMC
#
#                                       Unnamed: 4  \
# 0   *COURSE NATURE (Hard/Soft/\n Workshop/ NTCC)
# 1                                           HARD
# 2                                           HARD
# 3                                           SOFT
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                           HARD
# 8                                           HARD
# 9                                           HARD
# 10                                          HARD
# 11                                          NTCC
# 12                                           NaN
# 13                                          HARD
# 14                                          HARD
# 15                                          HARD
# 16                                          HARD
# 17                                          NTCC
# 18                                           NaN
# 19                                          HARD
# 20                                          HARD
# 21                                          HARD
# 22                                          HARD
# 23                                          NTCC
# 24                                           NaN
# 25                                          HARD
# 26                                          HARD
# 27                                          HARD
# 28                                          NTCC
# 29                                           NaN
# 30                                          HARD
# 31                                          HARD
# 32                                          HARD
# 33                                          HARD
# 34                                          NTCC
#
#                                            Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0   COURSE TYPE (Core/Elective /\n University Comp...          L          T
# 1                                                CORE          3          0
# 2                                                CORE          3          0
# 3                                                CORE          1          0
# 4                                                 NaN        NaN        NaN
# 5                                                 NaN        NaN        NaN
# 6                                                 NaN        NaN        NaN
# 7                                            ELECTIVE          3          0
# 8                                            ELECTIVE          3          0
# 9                                            ELECTIVE          3          0
# 10                                           ELECTIVE          3          0
# 11                                           ELECTIVE          0          0
# 12                                                NaN        NaN        NaN
# 13                                           ELECTIVE          3          0
# 14                                           ELECTIVE          3          0
# 15                                           ELECTIVE          3          0
# 16                                           ELECTIVE          3          0
# 17                                           ELECTIVE          0          0
# 18                                                NaN        NaN        NaN
# 19                                           ELECTIVE          3          0
# 20                                           ELECTIVE          3          0
# 21                                           ELECTIVE          3          0
# 22                                           ELECTIVE          3          0
# 23                                           ELECTIVE          0          0
# 24                                                NaN        NaN        NaN
# 25                                           ELECTIVE          3          0
# 26                                           ELECTIVE          3          0
# 27                                           ELECTIVE          3          0
# 28                                           ELECTIVE          0          0
# 29                                                NaN        NaN        NaN
# 30                                           ELECTIVE          3          0
# 31                                          ELECTIVE           3          0
# 32                                           ELECTIVE          2          0
# 33                                           ELECTIVE          2          0
# 34                                           ELECTIVE          0          0
#
#    Unnamed: 8                     Unnamed: 9     Unnamed: 10
# 0           P  NO. OF CONTACT HOURS PER WEEK  NO. OF CREDITS
# 1           0                              3               3
# 2           0                              3               3
# 3           2                              3               2
# 4         NaN                            NaN             NaN
# 5         NaN                            NaN             NaN
# 6         NaN                            NaN             NaN
# 7           0                              3               3
# 8           0                              3               3
# 9           0                              3               3
# 10          0                              3               3
# 11          0                              0               2
# 12        NaN                            NaN             NaN
# 13          0                              3               3
# 14          0                              3               3
# 15          0                              3               3
# 16          0                              3               3
# 17          0                              0               2
# 18        NaN                            NaN             NaN
# 19          0                              3               3
# 20          0                              3               3
# 21          0                              3               3
# 22          0                              3               3
# 23          0                              0               2
# 24        NaN                            NaN             NaN
# 25          0                              3               3
# 26          0                              3               3
# 27          0                              3               3
# 28          0                              0               2
# 29        NaN                            NaN             NaN
# 30          0                              3               3
# 31          0                              3               3
# 32          2                              4               3
# 33          2                              4               3
# 34          0                              0               2

# %%
unique_values = df['Unnamed: 2'].unique()

# Print unique values
print("Unique values from the column:")
for value in unique_values:
    print(value)
# Out:
# Unique values from the column:
# SUBJECT NAME
# HUMAN RESOURCE MANAGEMENT
# FINANCIAL MANAGEMENT
# ADVANCED EXCEL
# nan
# MACRO ECONOMICS
# COST  ACCOUNTING
# FINANCIAL SERVICES
# BUSINESS COMMUNICATION SKILLS- II
# INDUSTRY PROJECT
# INTRODUCTION TO  FAMILY BUSINESS MANAGEMENT (EFB)
# CREATIVITY & INNOVATION IN ENTREPRENEURSHIP
# FINANCING & BUSINESS DEVELOPMENT OF HOSPITALS
# HEALTHCARE COMMUNICATION
# Hospital Hazards and waste management
# HEALTHCARE ECONOMICS
# FUNDAMENTALS OF LOGISTICS
# MANAGERIAL ECONOMICS
# Structured Query Language (SQL)
# DATA CLEANING

# %%
import pandas as pd

# Create a DataFrame with your data
data = {
    'Name': ['John', 'Emma', 'Alice'],
    'Age': [30, 25, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}

df = pd.DataFrame(data)

# Define the filename for the Excel file
excel_filename = 'output.xlsx'

# Write the DataFrame to an Excel file
df.to_excel(excel_filename, index=False)

print(f"Data has been written to {excel_filename}")
# Out:
# Data has been written to output.xlsx
