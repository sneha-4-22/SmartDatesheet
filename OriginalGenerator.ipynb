# %%
# !pip install xlsxwriter 
import pandas as pd
import xlsxwriter
# Out:
# Collecting xlsxwriter
#   Obtaining dependency information for xlsxwriter from https://files.pythonhosted.org/packages/a7/ea/53d1fe468e63e092cf16e2c18d16f50c29851242f9dd12d6a66e0d7f0d02/XlsxWriter-3.2.0-py3-none-any.whl.metadata
#   Downloading XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# Downloading XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
#    ---------------------------------------- 0.0/159.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/159.9 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/159.9 kB ? eta -:--:--
#    ------- -------------------------------- 30.7/159.9 kB 1.3 MB/s eta 0:00:01
#    -------------- ------------------------ 61.4/159.9 kB 656.4 kB/s eta 0:00:01
#    ----------------------------- -------- 122.9/159.9 kB 717.5 kB/s eta 0:00:01
#    -------------------------------------- 159.9/159.9 kB 953.4 kB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.2.0

# %%
excel_file = 'Datesheet Generator.xlsx'

# %%
df = pd.read_excel(excel_file)

# %%
df
# Out:
#      S.No            Program Semester    Course Code  \
# 0       1     B.Sc Chemistry       IV      CHH205B-T
# 1       2     B.Sc Chemistry       IV      CHH206B-T
# 2       3     B.Sc Chemistry       IV      CHH207B-T
# 3       4     B.Sc Chemistry       IV        CHH209B
# 4       5     B.Sc Chemistry       VI        CHH310B
# ..    ...                ...      ...            ...
# 478   479  B.Tech CSE - CSTI       VI      CSH313B-T
# 479   480  B.Tech CSE - CSTI       VI        CSH314B
# 480   481  B.Tech CSE - CSTI       VI      CSH306B-T
# 481   482  B.Tech CSE - CSTI       VI  LWS323/LWS325
# 482   483  B.Tech CSE - CSTI       VI         CDO332
#
#                                            Course Name Course Type  \
# 0                               PHYSICAL CHEMISTRY III        Core
# 1                              INORGANIC CHEMISTRY III        Core
# 2                                ORGANIC CHEMISTRY III        Core
# 3                                 INDUSTRIAL CHEMISTRY    Elective
# 4                              Chemicals & Environment    Elective
# ..                                                 ...         ...
# 478                       DATA WAREHOUSE & DATA MINING    Elective
# 479                                   MACHINE LEARNING    Elective
# 480                    SYSTEM NETWORK & ADMINISTRATION    Elective
# 481  CYBER LAW/\nLAW RELATING TO INTELLECTUAL PROPE...    Elective
# 482             PROFESSIONAL COMPETANCY ENHANCEMENT-IV         CDC
#
#      No. of Students  L-T-P
# 0                9.0  3-1-0
# 1                9.0  3-1-0
# 2                9.0  0-0-3
# 3                9.0  3-1-0
# 4                5.0  3-1-0
# ..               ...    ...
# 478             30.0  3-0-2
# 479             30.0  3-0-2
# 480             30.0  3-0-2
# 481             30.0  2-0-0
# 482             30.0  6-0-0
#
# [483 rows x 8 columns]

# %%
df2 = pd.DataFrame()

# %%
df2["S.No"] = df["S.No"]

# %%
df2["Program"] = df["Program"]

# %%
df2["Semester"] = df["Semester"]

# %%
df2["Course Code"] = df["Course Code"]

# %%
df2["Course Name"] = df["Course Name"]

# %%
df2
# Out:
#      S.No            Program Semester    Course Code  \
# 0       1     B.Sc Chemistry       IV      CHH205B-T
# 1       2     B.Sc Chemistry       IV      CHH206B-T
# 2       3     B.Sc Chemistry       IV      CHH207B-T
# 3       4     B.Sc Chemistry       IV        CHH209B
# 4       5     B.Sc Chemistry       VI        CHH310B
# ..    ...                ...      ...            ...
# 478   479  B.Tech CSE - CSTI       VI      CSH313B-T
# 479   480  B.Tech CSE - CSTI       VI        CSH314B
# 480   481  B.Tech CSE - CSTI       VI      CSH306B-T
# 481   482  B.Tech CSE - CSTI       VI  LWS323/LWS325
# 482   483  B.Tech CSE - CSTI       VI         CDO332
#
#                                            Course Name
# 0                               PHYSICAL CHEMISTRY III
# 1                              INORGANIC CHEMISTRY III
# 2                                ORGANIC CHEMISTRY III
# 3                                 INDUSTRIAL CHEMISTRY
# 4                              Chemicals & Environment
# ..                                                 ...
# 478                       DATA WAREHOUSE & DATA MINING
# 479                                   MACHINE LEARNING
# 480                    SYSTEM NETWORK & ADMINISTRATION
# 481  CYBER LAW/\nLAW RELATING TO INTELLECTUAL PROPE...
# 482             PROFESSIONAL COMPETANCY ENHANCEMENT-IV
#
# [483 rows x 5 columns]

# %%
import numpy as np
import pandas as pd

# Assuming df2 is your DataFrame containing the data
df2[['L', 'T', 'P']] = df['L-T-P'].str.split('-', expand=True)
df2[['L', 'T', 'P']] = df2[['L', 'T', 'P']].apply(pd.to_numeric)
df2 = df2[(df2['L'] != 0) | (df2['T'] != 0)]

start_date = '2024-03-11'
end_date = '2024-04-28'
date_range = pd.date_range(start=start_date, end=end_date)
weekdays_range = date_range[date_range.dayofweek < 5]

# Define time slots
time_slots = [
    '9:00 - 10:30'
    
]

date_index = 0
time_slot_index = 0 
last_date = {} 
prev_program_semester = None  

for i, row in df2.iterrows():
    program_semester = (row["Program"], row["Semester"]) 
    
    if pd.isna(row["Course Name"]):  
        df2.at[i, 'Date'] = np.nan  
        date_index = 0  
    else:
        if program_semester != prev_program_semester:
            date_index = 0  
            prev_program_semester = program_semester
            time_slot_index = 0  # Reset the time slot index when program/semester changes
        
        if program_semester in last_date:
            last_assigned_date = last_date[program_semester] + pd.Timedelta(days=2) 
        else:
            last_assigned_date = pd.Timestamp(weekdays_range[0])  
        
        while True:
            if date_index >= len(weekdays_range):
                df2.at[i, 'Date'] = np.nan  
                break
            elif weekdays_range[date_index].dayofweek < 5:
                current_date = pd.Timestamp(weekdays_range[date_index].date())  
                if current_date >= last_assigned_date:
                    df2.at[i, 'Date'] = current_date  
                    last_date[program_semester] = current_date 
                    
                    # Assign time slot
                    df2.at[i, 'Time Slot'] = time_slots[time_slot_index]
                    
                    time_slot_index = (time_slot_index + 1) % len(time_slots)
                    
                    date_index += 1  
                    break
                else:
                    date_index += 1  
            else:
                date_index += 1  
                time_slot_index = 2 if time_slot_index == 0 else 0

# %%
df2
# Out:
#      S.No            Program Semester    Course Code  \
# 0       1     B.Sc Chemistry       IV      CHH205B-T
# 1       2     B.Sc Chemistry       IV      CHH206B-T
# 3       4     B.Sc Chemistry       IV        CHH209B
# 4       5     B.Sc Chemistry       VI        CHH310B
# 5       6     M.Sc Chemistry       II        CHH506B
# ..    ...                ...      ...            ...
# 478   479  B.Tech CSE - CSTI       VI      CSH313B-T
# 479   480  B.Tech CSE - CSTI       VI        CSH314B
# 480   481  B.Tech CSE - CSTI       VI      CSH306B-T
# 481   482  B.Tech CSE - CSTI       VI  LWS323/LWS325
# 482   483  B.Tech CSE - CSTI       VI         CDO332
#
#                                            Course Name       Date    L    T  \
# 0                               PHYSICAL CHEMISTRY III 2024-03-11  3.0  1.0
# 1                              INORGANIC CHEMISTRY III 2024-03-13  3.0  1.0
# 3                                 INDUSTRIAL CHEMISTRY 2024-03-15  3.0  1.0
# 4                              Chemicals & Environment 2024-03-11  3.0  1.0
# 5                                Physical Chemistry-II 2024-03-11  4.0  0.0
# ..                                                 ...        ...  ...  ...
# 478                       DATA WAREHOUSE & DATA MINING 2024-03-22  3.0  0.0
# 479                                   MACHINE LEARNING 2024-03-25  3.0  0.0
# 480                    SYSTEM NETWORK & ADMINISTRATION 2024-03-27  3.0  0.0
# 481  CYBER LAW/\nLAW RELATING TO INTELLECTUAL PROPE... 2024-03-29  2.0  0.0
# 482             PROFESSIONAL COMPETANCY ENHANCEMENT-IV 2024-04-01  6.0  0.0
#
#        P     Time Slot
# 0    0.0  9:00 - 10:30
# 1    0.0  9:00 - 10:30
# 3    0.0  9:00 - 10:30
# 4    0.0  9:00 - 10:30
# 5    0.0  9:00 - 10:30
# ..   ...           ...
# 478  2.0  9:00 - 10:30
# 479  2.0  9:00 - 10:30
# 480  2.0  9:00 - 10:30
# 481  0.0  9:00 - 10:30
# 482  0.0  9:00 - 10:30
#
# [469 rows x 10 columns]

# %%
excel_file_path = 'output_data.xlsx'

with pd.ExcelWriter(excel_file_path, engine='xlsxwriter') as writer:
    df2.to_excel(writer, index=False)
    worksheet = writer.sheets['Sheet1'] 
    worksheet.set_column('E:E', 6)
